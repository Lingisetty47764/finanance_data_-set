# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\lingi\Downloads\financial_loan.csv")

# %%
df
# Out:
#             id address_state application_type emp_length  \
# 0      1077430            GA       INDIVIDUAL   < 1 year
# 1      1072053            CA       INDIVIDUAL    9 years
# 2      1069243            CA       INDIVIDUAL    4 years
# 3      1041756            TX       INDIVIDUAL   < 1 year
# 4      1068350            IL       INDIVIDUAL  10+ years
# ...        ...           ...              ...        ...
# 38571   803452            NJ       INDIVIDUAL   < 1 year
# 38572   970377            NY       INDIVIDUAL    8 years
# 38573   875376            CA       INDIVIDUAL    5 years
# 38574   972997            NY       INDIVIDUAL    5 years
# 38575   682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership  issue_date  \
# 0                                Ryder     C           RENT  11-02-2021
# 1                       MKC Accounting     E           RENT  01-01-2021
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
df.shape
# Out:
# (38576, 24)

# %%
df.size
# Out:
# 925824

# %%
df.columns
# Out:
# Index(['id', 'address_state', 'application_type', 'emp_length', 'emp_title',
#        'grade', 'home_ownership', 'issue_date', 'last_credit_pull_date',
#        'last_payment_date', 'loan_status', 'next_payment_date', 'member_id',
#        'purpose', 'sub_grade', 'term', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                         int64
# address_state             object
# application_type          object
# emp_length                object
# emp_title                 object
# grade                     object
# home_ownership            object
# issue_date                object
# last_credit_pull_date     object
# last_payment_date         object
# loan_status               object
# next_payment_date         object
# member_id                  int64
# purpose                   object
# sub_grade                 object
# term                      object
# verification_status       object
# annual_income            float64
# dti                      float64
# installment              float64
# int_rate                 float64
# loan_amount                int64
# total_acc                  int64
# total_payment              int64
# dtype: object

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT  11-02-2021            13-09-2021        13-04-2021
# 1     E           RENT  01-01-2021            14-12-2021        15-01-2021
# 2     C           RENT  05-01-2021            12-12-2021        09-01-2021
# 3     B       MORTGAGE  25-02-2021            12-12-2021        12-03-2021
# 4     A       MORTGAGE  01-01-2021            14-12-2021        15-01-2021
#
# ...

# %%
df.describe()
# Out:
#                  id     member_id  annual_income           dti   installment  \
# count  3.857600e+04  3.857600e+04   3.857600e+04  38576.000000  38576.000000
# mean   6.810371e+05  8.476515e+05   6.964454e+04      0.133274    326.862965
# std    2.113246e+05  2.668105e+05   6.429368e+04      0.066662    209.092000
# min    5.473400e+04  7.069900e+04   4.000000e+03      0.000000     15.690000
# 25%    5.135170e+05  6.629788e+05   4.150000e+04      0.082100    168.450000
# 50%    6.627280e+05  8.473565e+05   6.000000e+04      0.134200    283.045000
# 75%    8.365060e+05  1.045652e+06   8.320050e+04      0.185900    434.442500
# max    1.077501e+06  1.314167e+06   6.000000e+06      0.299900   1305.190000
#
#            int_rate   loan_amount     total_acc  total_payment
# count  38576.000000  38576.000000  38576.000000   38576.000000
# mean       0.120488  11296.066855     22.132544   12263.348533
# std        0.037164   7460.746022     11.392282    9051.104777
# ...

# %% [markdown]
# # data exploration

# %%
df["home_ownership"].value_counts()
# Out:
# home_ownership
# RENT        18439
# MORTGAGE    17198
# OWN          2838
# OTHER          98
# NONE            3
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x=df["home_ownership"])
plt.title("house_wonership count ")
plt.show()

# %% [markdown]
# * from the above figure majority is the rent person in the home ownership

# %%
sns.countplot(x=df["emp_length"])
plt.title("emp_length count ")
plt.show()

# %%
df["emp_length"].value_counts()
# Out:
# emp_length
# 10+ years    8870
# < 1 year     4575
# 2 years      4382
# 3 years      4088
# 4 years      3428
# 5 years      3273
# 1 year       3229
# 6 years      2228
# 7 years      1772
# 8 years      1476
# 9 years      1255
# Name: count, dtype: int64

# %% [markdown]
# * from the above 10+ years have the moire count in the above employ length

# %%
sns.countplot(x=df["verification_status"])
plt.show()

# %% [markdown]
# * not verified having the more count fron the abovE figure

# %%
continous = df[["annual_income","dti","installment","int_rate","loan_amount","total_payment"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  object
#  8   last_credit_pull_date  38576 non-null  object
#  9   last_payment_date      38576 non-null  object
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  object
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
sns.catplot(x="loan_status",y="dti",kind="bar",data=df1)
plt.show()

# %% [markdown]
# * from the above the current paying members are high

# %%
sns.pairplot(df,vars=continous)
plt.show()

# %%
sns.relplot(x=df1["int_rate"],y=df1["dti"],col=df1["verification_status"],col_wrap=2,hue=df["loan_status"])
plt.show()

# %% [markdown]
# # droping unneed columns

# %%
df1=df.drop(columns={"id","application_type","grade","sub_grade","sub_grade"})

# %%
df1.tail()

# %%
df1["emp_length"].unique()
# Out:
# array(['< 1 year', '9 years', '4 years', '10+ years', '3 years',
#        '5 years', '1 year', '6 years', '2 years', '7 years', '8 years'],
#       dtype=object)

# %% [markdown]
# # data cleaning

# %%
df1.dtypes
# Out:
# address_state             object
# emp_length                object
# emp_title                 object
# home_ownership            object
# issue_date                object
# last_credit_pull_date     object
# last_payment_date         object
# loan_status               object
# next_payment_date         object
# member_id                  int64
# purpose                   object
# term                      object
# verification_status       object
# annual_income            float64
# dti                      float64
# installment              float64
# int_rate                 float64
# loan_amount                int64
# total_acc                  int64
# total_payment              int64
# dtype: object

# %%
df1["loan_status"].unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current'], dtype=object)

# %%
df1["home_ownership"].unique()
# Out:
# array(['RENT', 'MORTGAGE', 'OWN', 'OTHER', 'NONE'], dtype=object)

# %% [markdown]
# # dealing with the duplicates

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 38571    False
# 38572    False
# 38573    False
# 38574    False
# 38575    False
# Length: 38576, dtype: bool

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [address_state, emp_length, emp_title, home_ownership, issue_date, last_credit_pull_date, last_payment_date, loan_status, next_payment_date, member_id, purpose, term, verification_status, annual_income, dti, installment, int_rate, loan_amount, total_acc, total_payment]
# Index: []

# %% [markdown]
# # finding the non duplicated values

# %%
df1[~df1.duplicated()]
# Out:
#       address_state emp_length                        emp_title  \
# 0                GA   < 1 year                            Ryder
# 1                CA    9 years                   MKC Accounting
# 2                CA    4 years            Chemat Technology Inc
# 3                TX   < 1 year              barnes distribution
# 4                IL  10+ years                    J&J Steel Inc
# ...             ...        ...                              ...
# 38571            NJ   < 1 year         Joseph M Sanzari Company
# 38572            NY    8 years                        Swat Fame
# 38573            CA    5 years  Anaheim Regional Medical Center
# 38574            NY    5 years               Brooklyn Radiology
# 38575            NY    4 years                    Allen Edmonds
#
#       home_ownership  issue_date last_credit_pull_date last_payment_date  \
# 0               RENT  11-02-2021            13-09-2021        13-04-2021
# ...

# %% [markdown]
# # dealing with the missing values

# %%
df1.isnull()
# Out:
#        address_state  emp_length  emp_title  home_ownership  issue_date  \
# 0              False       False      False           False       False
# 1              False       False      False           False       False
# 2              False       False      False           False       False
# 3              False       False      False           False       False
# 4              False       False      False           False       False
# ...              ...         ...        ...             ...         ...
# 38571          False       False      False           False       False
# 38572          False       False      False           False       False
# 38573          False       False      False           False       False
# 38574          False       False      False           False       False
# 38575          False       False      False           False       False
#
#        last_credit_pull_date  last_payment_date  loan_status  \
# ...

# %%
df1.isnull().sum()
# Out:
# address_state               0
# emp_length                  0
# emp_title                1438
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %%
df1.isnull().sum()/len(df1)
# Out:
# address_state            0.000000
# emp_length               0.000000
# emp_title                0.037277
# home_ownership           0.000000
# issue_date               0.000000
# last_credit_pull_date    0.000000
# last_payment_date        0.000000
# loan_status              0.000000
# next_payment_date        0.000000
# member_id                0.000000
# purpose                  0.000000
# term                     0.000000
# verification_status      0.000000
# annual_income            0.000000
# dti                      0.000000
# installment              0.000000
# int_rate                 0.000000
# loan_amount              0.000000
# total_acc                0.000000
# total_payment            0.000000
# dtype: float64

# %% [markdown]
# * replacing stastically values with mode because of the discrete

# %%
df1["emp_title"].mode()
# Out:
# 0    US Army
# Name: emp_title, dtype: object

# %%
df1["emp_title"].value_counts()
# Out:
# emp_title
# US Army                           135
# Bank of America                   109
# IBM                                67
# AT&T                               63
# Wells Fargo                        57
#                                  ...
# Emeril's Delmonico's                1
# The Shafer Law Group                1
# U.S navy                            1
# Wellspring Healthcare Services      1
# Allen Edmonds                       1
# Name: count, Length: 28525, dtype: int64

# %%
df1["emp_title"].fillna(df1["emp_title"].mode())
# Out:
# 0                                  Ryder
# 1                         MKC Accounting
# 2                  Chemat Technology Inc
# 3                    barnes distribution
# 4                          J&J Steel Inc
#                       ...
# 38571           Joseph M Sanzari Company
# 38572                          Swat Fame
# 38573    Anaheim Regional Medical Center
# 38574                 Brooklyn Radiology
# 38575                      Allen Edmonds
# Name: emp_title, Length: 38576, dtype: object

# %%
df1["employ_title"] = df1["emp_title"].fillna("US Army")

# %%
df1["employ_title"].isnull().sum()
# Out:
# 0

# %%
df1.columns
# Out:
# Index(['address_state', 'emp_length', 'emp_title', 'home_ownership',
#        'issue_date', 'last_credit_pull_date', 'last_payment_date',
#        'loan_status', 'next_payment_date', 'member_id', 'purpose', 'term',
#        'verification_status', 'annual_income', 'dti', 'installment',
#        'int_rate', 'loan_amount', 'total_acc', 'total_payment',
#        'employ_title'],
#       dtype='object')

# %%
df1.drop(columns={"emp_title"})
# Out:
#       address_state emp_length home_ownership issue_date  \
# 0                GA   < 1 year           RENT 2021-02-11
# 1                CA    9 years           RENT 2021-01-01
# 2                CA    4 years           RENT 2021-01-05
# 3                TX   < 1 year       MORTGAGE 2021-02-25
# 4                IL  10+ years       MORTGAGE 2021-01-01
# ...             ...        ...            ...        ...
# 38571            NJ   < 1 year       MORTGAGE 2021-07-11
# 38572            NY    8 years           RENT 2021-10-11
# 38573            CA    5 years           RENT 2021-09-11
# 38574            NY    5 years           RENT 2021-10-11
# 38575            NY    4 years           RENT 2021-07-11
#
#       last_credit_pull_date last_payment_date  loan_status next_payment_date  \
# 0                2021-09-13        2021-04-13  Charged Off        2021-05-13
# 1                2021-12-14        2021-01-15   Fully Paid        2021-02-15
# ...

# %% [markdown]
# # feature selection

# %%
df1["issue_date"] = pd.to_datetime(df1["issue_date"],format="%d-%m-%Y")

# %%
df1["issue_date_MOT"] = df1["issue_date"].dt.day

# %%
df1["issue_date_MOM"] = df1["issue_date"].dt.month

# %%
df1["last_credit_pull_date"] = pd.to_datetime(df1["last_credit_pull_date"],format="%d-%m-%Y")

# %%
df1["last_credit_pull_date_MOT"] = df1["last_credit_pull_date"].dt.day

# %%
df1["last_credit_pull_date_MOM"] = df1["last_credit_pull_date"].dt.month

# %%
df1["last_payment_date"] = pd.to_datetime(df1["last_payment_date"],format="%d-%m-%Y")

# %%
df1["last_payment_date_MOT"] = df1["last_payment_date"].dt.day

# %%
df1["last_payment_date_MOM"] = df1["last_payment_date"].dt.month

# %%
df1["next_payment_date"] = pd.to_datetime(df1["next_payment_date"],format="%d-%m-%Y")

# %%
df1["next_payment_date_MOT"] = df1["next_payment_date"].dt.day

# %%
df1["next_payment_date_MOM"] = df1["next_payment_date"].dt.month

# %%
df1
# Out:
#       address_state emp_length                        emp_title  \
# 0                GA   < 1 year                            Ryder
# 1                CA    9 years                   MKC Accounting
# 2                CA    4 years            Chemat Technology Inc
# 3                TX   < 1 year              barnes distribution
# 4                IL  10+ years                    J&J Steel Inc
# ...             ...        ...                              ...
# 38571            NJ   < 1 year         Joseph M Sanzari Company
# 38572            NY    8 years                        Swat Fame
# 38573            CA    5 years  Anaheim Regional Medical Center
# 38574            NY    5 years               Brooklyn Radiology
# 38575            NY    4 years                    Allen Edmonds
#
#       home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0               RENT 2021-02-11            2021-09-13        2021-04-13
# ...

# %%
df1["issue_date_MOT"].value_counts()
# Out:
# issue_date_MOT
# 11    20850
# 10    11197
# 9      4706
# 8      1561
# 7       251
# 2         3
# 1         2
# 5         1
# 25        1
# 17        1
# 19        1
# 22        1
# 12        1
# Name: count, dtype: int64

# %%
df1["issue_date_MOM"].value_counts()
# Out:
# issue_date_MOM
# 12    4314
# 11    4035
# 10    3796
# 9     3536
# 8     3441
# 7     3366
# 6     3184
# 5     2911
# 4     2755
# 3     2627
# 1     2332
# 2     2279
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#   address_state emp_length              emp_title home_ownership issue_date  \
# 0            GA   < 1 year                  Ryder           RENT 2021-02-11
# 1            CA    9 years         MKC Accounting           RENT 2021-01-01
# 2            CA    4 years  Chemat Technology Inc           RENT 2021-01-05
# 3            TX   < 1 year    barnes distribution       MORTGAGE 2021-02-25
# 4            IL  10+ years          J&J Steel Inc       MORTGAGE 2021-01-01
#
#   last_credit_pull_date last_payment_date  loan_status next_payment_date  \
# 0            2021-09-13        2021-04-13  Charged Off        2021-05-13
# 1            2021-12-14        2021-01-15   Fully Paid        2021-02-15
# 2            2021-12-12        2021-01-09  Charged Off        2021-02-09
# 3            2021-12-12        2021-03-12   Fully Paid        2021-04-12
# 4            2021-12-14        2021-01-15   Fully Paid        2021-02-15
#
# ...

# %%
df=df1.drop(columns={"member_id"})

# %%
df.columns
# Out:
# Index(['address_state', 'emp_length', 'emp_title', 'home_ownership',
#        'issue_date', 'last_credit_pull_date', 'last_payment_date',
#        'loan_status', 'next_payment_date', 'purpose', 'term',
#        'verification_status', 'annual_income', 'dti', 'installment',
#        'int_rate', 'loan_amount', 'total_acc', 'total_payment', 'employ_title',
#        'issue_date_MOT', 'issue_date_MOM', 'last_credit_pull_date_MOT',
#        'last_credit_pull_date_MOM', 'last_payment_date_MOT',
#        'last_payment_date_MOM', 'next_payment_date_MOT',
#        'next_payment_date_MOM'],
#       dtype='object')

# %%
df.to_csv("finance_loan_cleaned_data.csv")

# %%
df.to_excel("finance_loan_cleaned_data.xlsx")
